# %%
# %matplotlib inline
import pandas as pd
import json
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # Using a Web API
#
# The objective for class today, is to augment the blockbuster box office data with an inflation adjusted price.  But rather than using the spreadsheet of data we found previously, today we will use a web API that does the conversion work for us.
#
# But before we dive into that lets take a step back and think about the following questions and concepts:
#
#         ○ Transferring data across the web
# 			§ Data representation  -- numbers / floats / strings
# 			§ Serialization
# 		○ Two main serialization technologies
# 			§ XML
# 			§ JSON
# 		○ JSON is the clear winner
# 		○ JSON and Python get along great
# 		○ Dictionaries are the key!
#
# 		○ What do we mean by an API ?
# 			§ Some website has data we want… Some website has the ability to compute something for us
# 			§ How do we ask the website to do some work for us?
# 			§ Query String
# 			§ REST (Representational State Transfer)  -- Next week

# %%
data= {'year': [1954, 1955, 2001], 'price': [0.38, 0.44, 2.59]}

# %%
data['price']
# Out:
# [0.38, 0.44, 2.59]

# %%
x = json.dumps(data)

# %%
type(x)
# Out:
# str

# %%
data = None

# %%
data = json.loads(x)

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['year', 'price'])

# %%
data['year']
# Out:
# [1954, 1955, 2001]

# %%
class Foo:
    def __init__(self,x,y,z):
        self.x = x
        self.y = y
        self.z = z

    def bar():
        pass

t = Foo(1,2,3)

# %%
t.__dict__
# Out:
# {'x': 1, 'y': 2, 'z': 3}

# %%
json.dumps(t.__dict__)
# Out:
# '{"y": 2, "x": 1, "z": 3}'

# %% [markdown]
# ###  Using requests to get some json data

# %%
r = requests.get("https://www.statbureau.org/get-data-json?country=united-states")

# %%
dir(r)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %% [markdown]
# We can look at the results with either ``r.text`` or EVEN BETTER ``r.json()`` which will parse the JSON text into a real data object.

# %%
r.json()
# Out:
# [{'Country': 0,
#   'InflationRate': -0.16221508641790922,
#   'InflationRateFormatted': '-0.16',
#   'InflationRateRounded': -0.16,
#   'Month': '/Date(1467345600000)/',
#   'MonthFormatted': '2016-07-01'},
#  {'Country': 0,
#   'InflationRate': 0.3338383922476232,
#   'InflationRateFormatted': '0.33',
#   'InflationRateRounded': 0.33,
#   'Month': '/Date(1464753600000)/',
#   'MonthFormatted': '2016-06-01'},
#  {'Country': 0,
#   'InflationRate': 0.40750477512005717,
#   'InflationRateFormatted': '0.41',
#   'InflationRateRounded': 0.41,
#   'Month': '/Date(1462075200000)/',
#   'MonthFormatted': '2016-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.4741067979104026,
#   'InflationRateFormatted': '0.47',
#   'InflationRateRounded': 0.47,
#   'Month': '/Date(1459483200000)/',
#   'MonthFormatted': '2016-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.4306000143392757,
#   'InflationRateFormatted': '0.43',
#   'InflationRateRounded': 0.43,
#   'Month': '/Date(1456808400000)/',
#   'MonthFormatted': '2016-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.08230765334548953,
#   'InflationRateFormatted': '0.08',
#   'InflationRateRounded': 0.08,
#   'Month': '/Date(1454302800000)/',
#   'MonthFormatted': '2016-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.16531022090688088,
#   'InflationRateFormatted': '0.17',
#   'InflationRateRounded': 0.17,
#   'Month': '/Date(1451624400000)/',
#   'MonthFormatted': '2016-01-01'},
#  {'Country': 0,
#   'InflationRate': -0.3417096437118684,
#   'InflationRateFormatted': '-0.34',
#   'InflationRateRounded': -0.34,
#   'Month': '/Date(1448946000000)/',
#   'MonthFormatted': '2015-12-01'},
#  {'Country': 0,
#   'InflationRate': -0.21106803790815598,
#   'InflationRateFormatted': '-0.21',
#   'InflationRateRounded': -0.21,
#   'Month': '/Date(1446350400000)/',
#   'MonthFormatted': '2015-11-01'},
#  {'Country': 0,
#   'InflationRate': -0.044968375044653175,
#   'InflationRateFormatted': '-0.04',
#   'InflationRateRounded': -0.04,
#   'Month': '/Date(1443672000000)/',
#   'MonthFormatted': '2015-10-01'},
#  {'Country': 0,
#   'InflationRate': -0.15567565753033788,
#   'InflationRateFormatted': '-0.16',
#   'InflationRateRounded': -0.16,
#   'Month': '/Date(1441080000000)/',
#   'MonthFormatted': '2015-09-01'},
#  {'Country': 0,
#   'InflationRate': -0.14162762828194791,
#   'InflationRateFormatted': '-0.14',
#   'InflationRateRounded': -0.14,
#   'Month': '/Date(1438401600000)/',
#   'MonthFormatted': '2015-08-01'},
#  {'Country': 0,
#   'InflationRate': 0.006704715929566959,
#   'InflationRateFormatted': '0.01',
#   'InflationRateRounded': 0.01,
#   'Month': '/Date(1435723200000)/',
#   'MonthFormatted': '2015-07-01'},
#  {'Country': 0,
#   'InflationRate': 0.3502869998528206,
#   'InflationRateFormatted': '0.35',
#   'InflationRateRounded': 0.35,
#   'Month': '/Date(1433131200000)/',
#   'MonthFormatted': '2015-06-01'},
#  {'Country': 0,
#   'InflationRate': 0.5097232025494614,
#   'InflationRateFormatted': '0.51',
#   'InflationRateRounded': 0.51,
#   'Month': '/Date(1430452800000)/',
#   'MonthFormatted': '2015-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.2032873254587729,
#   'InflationRateFormatted': '0.20',
#   'InflationRateRounded': 0.2,
#   'Month': '/Date(1427860800000)/',
#   'MonthFormatted': '2015-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.5951721611097384,
#   'InflationRateFormatted': '0.60',
#   'InflationRateRounded': 0.6,
#   'Month': '/Date(1425186000000)/',
#   'MonthFormatted': '2015-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.43430449237720736,
#   'InflationRateFormatted': '0.43',
#   'InflationRateRounded': 0.43,
#   'Month': '/Date(1422766800000)/',
#   'MonthFormatted': '2015-02-01'},
#  {'Country': 0,
#   'InflationRate': -0.47058923734732466,
#   'InflationRateFormatted': '-0.47',
#   'InflationRateRounded': -0.47,
#   'Month': '/Date(1420088400000)/',
#   'MonthFormatted': '2015-01-01'},
#  {'Country': 0,
#   'InflationRate': -0.5670100910010968,
#   'InflationRateFormatted': '-0.57',
#   'InflationRateRounded': -0.57,
#   'Month': '/Date(1417410000000)/',
#   'MonthFormatted': '2014-12-01'},
#  {'Country': 0,
#   'InflationRate': -0.5399417941061267,
#   'InflationRateFormatted': '-0.54',
#   'InflationRateRounded': -0.54,
#   'Month': '/Date(1414814400000)/',
#   'MonthFormatted': '2014-11-01'},
#  {'Country': 0,
#   'InflationRate': -0.2512277812553827,
#   'InflationRateFormatted': '-0.25',
#   'InflationRateRounded': -0.25,
#   'Month': '/Date(1412136000000)/',
#   'MonthFormatted': '2014-10-01'},
#  {'Country': 0,
#   'InflationRate': 0.0752568824310916,
#   'InflationRateFormatted': '0.08',
#   'InflationRateRounded': 0.08,
#   'Month': '/Date(1409544000000)/',
#   'MonthFormatted': '2014-09-01'},
#  {'Country': 0,
#   'InflationRate': -0.1670514165792235,
#   'InflationRateFormatted': '-0.17',
#   'InflationRateRounded': -0.17,
#   'Month': '/Date(1406865600000)/',
#   'MonthFormatted': '2014-08-01'},
#  {'Country': 0,
#   'InflationRate': -0.03901939641608942,
#   'InflationRateFormatted': '-0.04',
#   'InflationRateRounded': -0.04,
#   'Month': '/Date(1404187200000)/',
#   'MonthFormatted': '2014-07-01'},
#  {'Country': 0,
#   'InflationRate': 0.1862126944094157,
#   'InflationRateFormatted': '0.19',
#   'InflationRateRounded': 0.19,
#   'Month': '/Date(1401595200000)/',
#   'MonthFormatted': '2014-06-01'},
#  {'Country': 0,
#   'InflationRate': 0.3492609840048593,
#   'InflationRateFormatted': '0.35',
#   'InflationRateRounded': 0.35,
#   'Month': '/Date(1398916800000)/',
#   'MonthFormatted': '2014-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.3296754453157732,
#   'InflationRateFormatted': '0.33',
#   'InflationRateRounded': 0.33,
#   'Month': '/Date(1396324800000)/',
#   'MonthFormatted': '2014-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.6440044126228273,
#   'InflationRateFormatted': '0.64',
#   'InflationRateRounded': 0.64,
#   'Month': '/Date(1393650000000)/',
#   'MonthFormatted': '2014-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.36979086509687237,
#   'InflationRateFormatted': '0.37',
#   'InflationRateRounded': 0.37,
#   'Month': '/Date(1391230800000)/',
#   'MonthFormatted': '2014-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.37202476732361006,
#   'InflationRateFormatted': '0.37',
#   'InflationRateRounded': 0.37,
#   'Month': '/Date(1388552400000)/',
#   'MonthFormatted': '2014-01-01'},
#  {'Country': 0,
#   'InflationRate': -0.008581149788260129,
#   'InflationRateFormatted': '-0.01',
#   'InflationRateRounded': -0.01,
#   'Month': '/Date(1385874000000)/',
#   'MonthFormatted': '2013-12-01'},
#  {'Country': 0,
#   'InflationRate': -0.20424241905234944,
#   'InflationRateFormatted': '-0.20',
#   'InflationRateRounded': -0.2,
#   'Month': '/Date(1383278400000)/',
#   'MonthFormatted': '2013-11-01'},
#  {'Country': 0,
#   'InflationRate': -0.25752832598046543,
#   'InflationRateFormatted': '-0.26',
#   'InflationRateRounded': -0.26,
#   'Month': '/Date(1380600000000)/',
#   'MonthFormatted': '2013-10-01'},
#  {'Country': 0,
#   'InflationRate': 0.11630044852636215,
#   'InflationRateFormatted': '0.12',
#   'InflationRateRounded': 0.12,
#   'Month': '/Date(1378008000000)/',
#   'MonthFormatted': '2013-09-01'},
#  {'Country': 0,
#   'InflationRate': 0.12029315570472097,
#   'InflationRateFormatted': '0.12',
#   'InflationRateRounded': 0.12,
#   'Month': '/Date(1375329600000)/',
#   'MonthFormatted': '2013-08-01'},
#  {'Country': 0,
#   'InflationRate': 0.03939975332328354,
#   'InflationRateFormatted': '0.04',
#   'InflationRateRounded': 0.04,
#   'Month': '/Date(1372651200000)/',
#   'MonthFormatted': '2013-07-01'},
#  {'Country': 0,
#   'InflationRate': 0.2399708085599605,
#   'InflationRateFormatted': '0.24',
#   'InflationRateRounded': 0.24,
#   'Month': '/Date(1370059200000)/',
#   'MonthFormatted': '2013-06-01'},
#  {'Country': 0,
#   'InflationRate': 0.17804077735871776,
#   'InflationRateFormatted': '0.18',
#   'InflationRateRounded': 0.18,
#   'Month': '/Date(1367380800000)/',
#   'MonthFormatted': '2013-05-01'},
#  {'Country': 0,
#   'InflationRate': -0.10396394770871192,
#   'InflationRateFormatted': '-0.10',
#   'InflationRateRounded': -0.1,
#   'Month': '/Date(1364788800000)/',
#   'MonthFormatted': '2013-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.2614508584374973,
#   'InflationRateFormatted': '0.26',
#   'InflationRateRounded': 0.26,
#   'Month': '/Date(1362114000000)/',
#   'MonthFormatted': '2013-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.8190029529268716,
#   'InflationRateFormatted': '0.82',
#   'InflationRateRounded': 0.82,
#   'Month': '/Date(1359694800000)/',
#   'MonthFormatted': '2013-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.2957304192925989,
#   'InflationRateFormatted': '0.30',
#   'InflationRateRounded': 0.3,
#   'Month': '/Date(1357016400000)/',
#   'MonthFormatted': '2013-01-01'},
#  {'Country': 0,
#   'InflationRate': -0.2693064490207236,
#   'InflationRateFormatted': '-0.27',
#   'InflationRateRounded': -0.27,
#   'Month': '/Date(1354338000000)/',
#   'MonthFormatted': '2012-12-01'},
#  {'Country': 0,
#   'InflationRate': -0.4738086694881915,
#   'InflationRateFormatted': '-0.47',
#   'InflationRateRounded': -0.47,
#   'Month': '/Date(1351742400000)/',
#   'MonthFormatted': '2012-11-01'},
#  {'Country': 0,
#   'InflationRate': -0.03889251405532244,
#   'InflationRateFormatted': '-0.04',
#   'InflationRateRounded': -0.04,
#   'Month': '/Date(1349064000000)/',
#   'MonthFormatted': '2012-10-01'},
#  {'Country': 0,
#   'InflationRate': 0.4462212267611197,
#   'InflationRateFormatted': '0.45',
#   'InflationRateRounded': 0.45,
#   'Month': '/Date(1346472000000)/',
#   'MonthFormatted': '2012-09-01'},
#  {'Country': 0,
#   'InflationRate': 0.5565158181437251,
#   'InflationRateFormatted': '0.56',
#   'InflationRateRounded': 0.56,
#   'Month': '/Date(1343793600000)/',
#   'MonthFormatted': '2012-08-01'},
#  {'Country': 0,
#   'InflationRate': -0.16297858618255345,
#   'InflationRateFormatted': '-0.16',
#   'InflationRateRounded': -0.16,
#   'Month': '/Date(1341115200000)/',
#   'MonthFormatted': '2012-07-01'},
#  {'Country': 0,
#   'InflationRate': -0.14663968844505362,
#   'InflationRateFormatted': '-0.15',
#   'InflationRateRounded': -0.15,
#   'Month': '/Date(1338523200000)/',
#   'MonthFormatted': '2012-06-01'},
#  {'Country': 0,
#   'InflationRate': -0.11734793663211422,
#   'InflationRateFormatted': '-0.12',
#   'InflationRateRounded': -0.12,
#   'Month': '/Date(1335844800000)/',
#   'MonthFormatted': '2012-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.30210295040803514,
#   'InflationRateFormatted': '0.30',
#   'InflationRateRounded': 0.3,
#   'Month': '/Date(1333252800000)/',
#   'MonthFormatted': '2012-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.7594558623930986,
#   'InflationRateFormatted': '0.76',
#   'InflationRateRounded': 0.76,
#   'Month': '/Date(1330578000000)/',
#   'MonthFormatted': '2012-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.44029735512761126,
#   'InflationRateFormatted': '0.44',
#   'InflationRateRounded': 0.44,
#   'Month': '/Date(1328072400000)/',
#   'MonthFormatted': '2012-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.4400191428267574,
#   'InflationRateFormatted': '0.44',
#   'InflationRateRounded': 0.44,
#   'Month': '/Date(1325394000000)/',
#   'MonthFormatted': '2012-01-01'},
#  {'Country': 0,
#   'InflationRate': -0.24665163771383106,
#   'InflationRateFormatted': '-0.25',
#   'InflationRateRounded': -0.25,
#   'Month': '/Date(1322715600000)/',
#   'MonthFormatted': '2011-12-01'},
#  {'Country': 0,
#   'InflationRate': -0.08435613304419642,
#   'InflationRateFormatted': '-0.08',
#   'InflationRateRounded': -0.08,
#   'Month': '/Date(1320120000000)/',
#   'MonthFormatted': '2011-11-01'},
#  {'Country': 0,
#   'InflationRate': -0.2062682633358162,
#   'InflationRateFormatted': '-0.21',
#   'InflationRateRounded': -0.21,
#   'Month': '/Date(1317441600000)/',
#   'MonthFormatted': '2011-10-01'},
#  {'Country': 0,
#   'InflationRate': 0.15184621156944536,
#   'InflationRateFormatted': '0.15',
#   'InflationRateRounded': 0.15,
#   'Month': '/Date(1314849600000)/',
#   'MonthFormatted': '2011-09-01'},
#  {'Country': 0,
#   'InflationRate': 0.2757588902364533,
#   'InflationRateFormatted': '0.28',
#   'InflationRateRounded': 0.28,
#   'Month': '/Date(1312171200000)/',
#   'MonthFormatted': '2011-08-01'},
#  {'Country': 0,
#   'InflationRate': 0.08860456667936666,
#   'InflationRateFormatted': '0.09',
#   'InflationRateRounded': 0.09,
#   'Month': '/Date(1309492800000)/',
#   'MonthFormatted': '2011-07-01'},
#  {'Country': 0,
#   'InflationRate': -0.10709670566992972,
#   'InflationRateFormatted': '-0.11',
#   'InflationRateRounded': -0.11,
#   'Month': '/Date(1306900800000)/',
#   'MonthFormatted': '2011-06-01'},
#  {'Country': 0,
#   'InflationRate': 0.47041875272336,
#   'InflationRateFormatted': '0.47',
#   'InflationRateRounded': 0.47,
#   'Month': '/Date(1304222400000)/',
#   'MonthFormatted': '2011-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.6439429535457137,
#   'InflationRateFormatted': '0.64',
#   'InflationRateRounded': 0.64,
#   'Month': '/Date(1301630400000)/',
#   'MonthFormatted': '2011-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.9751072030509378,
#   'InflationRateFormatted': '0.98',
#   'InflationRateRounded': 0.98,
#   'Month': '/Date(1298955600000)/',
#   'MonthFormatted': '2011-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.4931365025451474,
#   'InflationRateFormatted': '0.49',
#   'InflationRateRounded': 0.49,
#   'Month': '/Date(1296536400000)/',
#   'MonthFormatted': '2011-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.4763230053974149,
#   'InflationRateFormatted': '0.48',
#   'InflationRateRounded': 0.48,
#   'Month': '/Date(1293858000000)/',
#   'MonthFormatted': '2011-01-01'},
#  {'Country': 0,
#   'InflationRate': 0.1718440789203073,
#   'InflationRateFormatted': '0.17',
#   'InflationRateRounded': 0.17,
#   'Month': '/Date(1291179600000)/',
#   'MonthFormatted': '2010-12-01'},
#  {'Country': 0,
#   'InflationRate': 0.0420646423819561,
#   'InflationRateFormatted': '0.04',
#   'InflationRateRounded': 0.04,
#   'Month': '/Date(1288584000000)/',
#   'MonthFormatted': '2010-11-01'},
#  {'Country': 0,
#   'InflationRate': 0.12451988884768746,
#   'InflationRateFormatted': '0.12',
#   'InflationRateRounded': 0.12,
#   'Month': '/Date(1285905600000)/',
#   'MonthFormatted': '2010-10-01'},
#  {'Country': 0,
#   'InflationRate': 0.0581736230715673,
#   'InflationRateFormatted': '0.06',
#   'InflationRateRounded': 0.06,
#   'Month': '/Date(1283313600000)/',
#   'MonthFormatted': '2010-09-01'},
#  {'Country': 0,
#   'InflationRate': 0.13806642784079703,
#   'InflationRateFormatted': '0.14',
#   'InflationRateRounded': 0.14,
#   'Month': '/Date(1280635200000)/',
#   'MonthFormatted': '2010-08-01'},
#  {'Country': 0,
#   'InflationRate': 0.021104305737159636,
#   'InflationRateFormatted': '0.02',
#   'InflationRateRounded': 0.02,
#   'Month': '/Date(1277956800000)/',
#   'MonthFormatted': '2010-07-01'},
#  {'Country': 0,
#   'InflationRate': -0.09762670846739818,
#   'InflationRateFormatted': '-0.10',
#   'InflationRateRounded': -0.1,
#   'Month': '/Date(1275364800000)/',
#   'MonthFormatted': '2010-06-01'},
#  {'Country': 0,
#   'InflationRate': 0.0775197354237669,
#   'InflationRateFormatted': '0.08',
#   'InflationRateRounded': 0.08,
#   'Month': '/Date(1272686400000)/',
#   'MonthFormatted': '2010-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.1736884910697465,
#   'InflationRateFormatted': '0.17',
#   'InflationRateRounded': 0.17,
#   'Month': '/Date(1270094400000)/',
#   'MonthFormatted': '2010-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.41062835365712996,
#   'InflationRateFormatted': '0.41',
#   'InflationRateRounded': 0.41,
#   'Month': '/Date(1267419600000)/',
#   'MonthFormatted': '2010-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.024920738207645128,
#   'InflationRateFormatted': '0.02',
#   'InflationRateRounded': 0.02,
#   'Month': '/Date(1265000400000)/',
#   'MonthFormatted': '2010-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.3417473570148507,
#   'InflationRateFormatted': '0.34',
#   'InflationRateRounded': 0.34,
#   'Month': '/Date(1262322000000)/',
#   'MonthFormatted': '2010-01-01'},
#  {'Country': 0,
#   'InflationRate': -0.176119816946332,
#   'InflationRateFormatted': '-0.18',
#   'InflationRateRounded': -0.18,
#   'Month': '/Date(1259643600000)/',
#   'MonthFormatted': '2009-12-01'},
#  {'Country': 0,
#   'InflationRate': 0.07077533687672602,
#   'InflationRateFormatted': '0.07',
#   'InflationRateRounded': 0.07,
#   'Month': '/Date(1257048000000)/',
#   'MonthFormatted': '2009-11-01'},
#  {'Country': 0,
#   'InflationRate': 0.0963101185818335,
#   'InflationRateFormatted': '0.10',
#   'InflationRateRounded': 0.1,
#   'Month': '/Date(1254369600000)/',
#   'MonthFormatted': '2009-10-01'},
#  {'Country': 0,
#   'InflationRate': 0.06254806934959274,
#   'InflationRateFormatted': '0.06',
#   'InflationRateRounded': 0.06,
#   'Month': '/Date(1251777600000)/',
#   'MonthFormatted': '2009-09-01'},
#  {'Country': 0,
#   'InflationRate': 0.2242850044810565,
#   'InflationRateFormatted': '0.22',
#   'InflationRateRounded': 0.22,
#   'Month': '/Date(1249099200000)/',
#   'MonthFormatted': '2009-08-01'},
#  {'Country': 0,
#   'InflationRate': -0.15855869221532456,
#   'InflationRateFormatted': '-0.16',
#   'InflationRateRounded': -0.16,
#   'Month': '/Date(1246420800000)/',
#   'MonthFormatted': '2009-07-01'},
#  {'Country': 0,
#   'InflationRate': 0.8589892263953315,
#   'InflationRateFormatted': '0.86',
#   'InflationRateRounded': 0.86,
#   'Month': '/Date(1243828800000)/',
#   'MonthFormatted': '2009-06-01'},
#  {'Country': 0,
#   'InflationRate': 0.28887638341774524,
#   'InflationRateFormatted': '0.29',
#   'InflationRateRounded': 0.29,
#   'Month': '/Date(1241150400000)/',
#   'MonthFormatted': '2009-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.2496368277787964,
#   'InflationRateFormatted': '0.25',
#   'InflationRateRounded': 0.25,
#   'Month': '/Date(1238558400000)/',
#   'MonthFormatted': '2009-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.24317484554155885,
#   'InflationRateFormatted': '0.24',
#   'InflationRateRounded': 0.24,
#   'Month': '/Date(1235883600000)/',
#   'MonthFormatted': '2009-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.49729330359045765,
#   'InflationRateFormatted': '0.50',
#   'InflationRateRounded': 0.5,
#   'Month': '/Date(1233464400000)/',
#   'MonthFormatted': '2009-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.43524173754209716,
#   'InflationRateFormatted': '0.44',
#   'InflationRateRounded': 0.44,
#   'Month': '/Date(1230786000000)/',
#   'MonthFormatted': '2009-01-01'},
#  {'Country': 0,
#   'InflationRate': -1.0342473814287396,
#   'InflationRateFormatted': '-1.03',
#   'InflationRateRounded': -1.03,
#   'Month': '/Date(1228107600000)/',
#   'MonthFormatted': '2008-12-01'},
#  {'Country': 0,
#   'InflationRate': -1.91528953285959,
#   'InflationRateFormatted': '-1.92',
#   'InflationRateRounded': -1.92,
#   'Month': '/Date(1225512000000)/',
#   'MonthFormatted': '2008-11-01'},
#  {'Country': 0,
#   'InflationRate': -1.0101333284578784,
#   'InflationRateFormatted': '-1.01',
#   'InflationRateRounded': -1.01,
#   'Month': '/Date(1222833600000)/',
#   'MonthFormatted': '2008-10-01'},
#  {'Country': 0,
#   'InflationRate': -0.13830185406643966,
#   'InflationRateFormatted': '-0.14',
#   'InflationRateRounded': -0.14,
#   'Month': '/Date(1220241600000)/',
#   'MonthFormatted': '2008-09-01'},
#  {'Country': 0,
#   'InflationRate': -0.39915622556418323,
#   'InflationRateFormatted': '-0.40',
#   'InflationRateRounded': -0.4,
#   'Month': '/Date(1217563200000)/',
#   'MonthFormatted': '2008-08-01'},
#  {'Country': 0,
#   'InflationRate': 0.525101112812193,
#   'InflationRateFormatted': '0.53',
#   'InflationRateRounded': 0.53,
#   'Month': '/Date(1214884800000)/',
#   'MonthFormatted': '2008-07-01'},
#  {'Country': 0,
#   'InflationRate': 1.0076996934894198,
#   'InflationRateFormatted': '1.01',
#   'InflationRateRounded': 1.01,
#   'Month': '/Date(1212292800000)/',
#   'MonthFormatted': '2008-06-01'},
#  {'Country': 0,
#   'InflationRate': 0.8420886031756376,
#   'InflationRateFormatted': '0.84',
#   'InflationRateRounded': 0.84,
#   'Month': '/Date(1209614400000)/',
#   'MonthFormatted': '2008-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.6064778389719381,
#   'InflationRateFormatted': '0.61',
#   'InflationRateRounded': 0.61,
#   'Month': '/Date(1207022400000)/',
#   'MonthFormatted': '2008-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.8668212930989688,
#   'InflationRateFormatted': '0.87',
#   'InflationRateRounded': 0.87,
#   'Month': '/Date(1204347600000)/',
#   'MonthFormatted': '2008-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.2904112184953572,
#   'InflationRateFormatted': '0.29',
#   'InflationRateRounded': 0.29,
#   'Month': '/Date(1201842000000)/',
#   'MonthFormatted': '2008-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.49705764726046964,
#   'InflationRateFormatted': '0.50',
#   'InflationRateRounded': 0.5,
#   'Month': '/Date(1199163600000)/',
#   'MonthFormatted': '2008-01-01'},
#  {'Country': 0,
#   'InflationRate': -0.06708631296478683,
#   'InflationRateFormatted': '-0.07',
#   'InflationRateRounded': -0.07,
#   'Month': '/Date(1196485200000)/',
#   'MonthFormatted': '2007-12-01'},
#  {'Country': 0,
#   'InflationRate': 0.5939617873415782,
#   'InflationRateFormatted': '0.59',
#   'InflationRateRounded': 0.59,
#   'Month': '/Date(1193889600000)/',
#   'MonthFormatted': '2007-11-01'},
#  {'Country': 0,
#   'InflationRate': 0.2139191328121253,
#   'InflationRateFormatted': '0.21',
#   'InflationRateRounded': 0.21,
#   'Month': '/Date(1191211200000)/',
#   'MonthFormatted': '2007-10-01'},
#  {'Country': 0,
#   'InflationRate': 0.2755907405358869,
#   'InflationRateFormatted': '0.28',
#   'InflationRateRounded': 0.28,
#   'Month': '/Date(1188619200000)/',
#   'MonthFormatted': '2007-09-01'},
#  {'Country': 0,
#   'InflationRate': -0.1833902227087024,
#   'InflationRateFormatted': '-0.18',
#   'InflationRateRounded': -0.18,
#   'Month': '/Date(1185940800000)/',
#   'MonthFormatted': '2007-08-01'},
#  {'Country': 0,
#   'InflationRate': -0.025437720780218092,
#   'InflationRateFormatted': '-0.03',
#   'InflationRateRounded': -0.03,
#   'Month': '/Date(1183262400000)/',
#   'MonthFormatted': '2007-07-01'},
#  {'Country': 0,
#   'InflationRate': 0.19379751766058023,
#   'InflationRateFormatted': '0.19',
#   'InflationRateRounded': 0.19,
#   'Month': '/Date(1180670400000)/',
#   'MonthFormatted': '2007-06-01'},
#  {'Country': 0,
#   'InflationRate': 0.6110718674704625,
#   'InflationRateFormatted': '0.61',
#   'InflationRateRounded': 0.61,
#   'Month': '/Date(1177992000000)/',
#   'MonthFormatted': '2007-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.6496162686509018,
#   'InflationRateFormatted': '0.65',
#   'InflationRateRounded': 0.65,
#   'Month': '/Date(1175400000000)/',
#   'MonthFormatted': '2007-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.9105695851085264,
#   'InflationRateFormatted': '0.91',
#   'InflationRateRounded': 0.91,
#   'Month': '/Date(1172725200000)/',
#   'MonthFormatted': '2007-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.535036755987669,
#   'InflationRateFormatted': '0.54',
#   'InflationRateRounded': 0.54,
#   'Month': '/Date(1170306000000)/',
#   'MonthFormatted': '2007-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.30525272547076315,
#   'InflationRateFormatted': '0.31',
#   'InflationRateRounded': 0.31,
#   'Month': '/Date(1167627600000)/',
#   'MonthFormatted': '2007-01-01'},
#  {'Country': 0,
#   'InflationRate': 0.1488833746898263,
#   'InflationRateFormatted': '0.15',
#   'InflationRateRounded': 0.15,
#   'Month': '/Date(1164949200000)/',
#   'MonthFormatted': '2006-12-01'},
#  {'Country': 0,
#   'InflationRate': -0.14866204162537167,
#   'InflationRateFormatted': '-0.15',
#   'InflationRateRounded': -0.15,
#   'Month': '/Date(1162357200000)/',
#   'MonthFormatted': '2006-11-01'},
#  {'Country': 0,
#   'InflationRate': -0.5421389847215377,
#   'InflationRateFormatted': '-0.54',
#   'InflationRateRounded': -0.54,
#   'Month': '/Date(1159675200000)/',
#   'MonthFormatted': '2006-10-01'},
#  {'Country': 0,
#   'InflationRate': -0.4904364884747425,
#   'InflationRateFormatted': '-0.49',
#   'InflationRateRounded': -0.49,
#   'Month': '/Date(1157083200000)/',
#   'MonthFormatted': '2006-09-01'},
#  {'Country': 0,
#   'InflationRate': 0.19656019656019655,
#   'InflationRateFormatted': '0.20',
#   'InflationRateRounded': 0.2,
#   'Month': '/Date(1154404800000)/',
#   'MonthFormatted': '2006-08-01'},
#  {'Country': 0,
#   'InflationRate': 0.2957121734844751,
#   'InflationRateFormatted': '0.30',
#   'InflationRateRounded': 0.3,
#   'Month': '/Date(1151726400000)/',
#   'MonthFormatted': '2006-07-01'},
#  {'Country': 0,
#   'InflationRate': 0.19753086419753085,
#   'InflationRateFormatted': '0.20',
#   'InflationRateRounded': 0.2,
#   'Month': '/Date(1149134400000)/',
#   'MonthFormatted': '2006-06-01'},
#  {'Country': 0,
#   'InflationRate': 0.49627791563275436,
#   'InflationRateFormatted': '0.50',
#   'InflationRateRounded': 0.5,
#   'Month': '/Date(1146456000000)/',
#   'MonthFormatted': '2006-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.8508508508508509,
#   'InflationRateFormatted': '0.85',
#   'InflationRateRounded': 0.85,
#   'Month': '/Date(1143867600000)/',
#   'MonthFormatted': '2006-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.5535983895319577,
#   'InflationRateFormatted': '0.55',
#   'InflationRateRounded': 0.55,
#   'Month': '/Date(1141189200000)/',
#   'MonthFormatted': '2006-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.20171457387796268,
#   'InflationRateFormatted': '0.20',
#   'InflationRateRounded': 0.2,
#   'Month': '/Date(1138770000000)/',
#   'MonthFormatted': '2006-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.7621951219512195,
#   'InflationRateFormatted': '0.76',
#   'InflationRateRounded': 0.76,
#   'Month': '/Date(1136091600000)/',
#   'MonthFormatted': '2006-01-01'},
#  {'Country': 0,
#   'InflationRate': -0.4048582995951417,
#   'InflationRateFormatted': '-0.40',
#   'InflationRateRounded': -0.4,
#   'Month': '/Date(1133413200000)/',
#   'MonthFormatted': '2005-12-01'},
#  {'Country': 0,
#   'InflationRate': -0.8032128514056225,
#   'InflationRateFormatted': '-0.80',
#   'InflationRateRounded': -0.8,
#   'Month': '/Date(1130821200000)/',
#   'MonthFormatted': '2005-11-01'},
#  {'Country': 0,
#   'InflationRate': 0.2012072434607646,
#   'InflationRateFormatted': '0.20',
#   'InflationRateRounded': 0.2,
#   'Month': '/Date(1128139200000)/',
#   'MonthFormatted': '2005-10-01'},
#  {'Country': 0,
#   'InflationRate': 1.2219959266802445,
#   'InflationRateFormatted': '1.22',
#   'InflationRateRounded': 1.22,
#   'Month': '/Date(1125547200000)/',
#   'MonthFormatted': '2005-09-01'},
#  {'Country': 0,
#   'InflationRate': 0.5117707267144319,
#   'InflationRateFormatted': '0.51',
#   'InflationRateRounded': 0.51,
#   'Month': '/Date(1122868800000)/',
#   'MonthFormatted': '2005-08-01'},
#  {'Country': 0,
#   'InflationRate': 0.46272493573264784,
#   'InflationRateFormatted': '0.46',
#   'InflationRateRounded': 0.46,
#   'Month': '/Date(1120190400000)/',
#   'MonthFormatted': '2005-07-01'},
#  {'Country': 0,
#   'InflationRate': 0.051440329218107,
#   'InflationRateFormatted': '0.05',
#   'InflationRateRounded': 0.05,
#   'Month': '/Date(1117598400000)/',
#   'MonthFormatted': '2005-06-01'},
#  {'Country': 0,
#   'InflationRate': -0.10277492291880781,
#   'InflationRateFormatted': '-0.10',
#   'InflationRateRounded': -0.1,
#   'Month': '/Date(1114920000000)/',
#   'MonthFormatted': '2005-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.6725297465080187,
#   'InflationRateFormatted': '0.67',
#   'InflationRateRounded': 0.67,
#   'Month': '/Date(1112331600000)/',
#   'MonthFormatted': '2005-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.7820646506777894,
#   'InflationRateFormatted': '0.78',
#   'InflationRateRounded': 0.78,
#   'Month': '/Date(1109653200000)/',
#   'MonthFormatted': '2005-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.5768222338751966,
#   'InflationRateFormatted': '0.58',
#   'InflationRateRounded': 0.58,
#   'Month': '/Date(1107234000000)/',
#   'MonthFormatted': '2005-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.21019442984760903,
#   'InflationRateFormatted': '0.21',
#   'InflationRateRounded': 0.21,
#   'Month': '/Date(1104555600000)/',
#   'MonthFormatted': '2005-01-01'},
#  {'Country': 0,
#   'InflationRate': -0.36649214659685864,
#   'InflationRateFormatted': '-0.37',
#   'InflationRateRounded': -0.37,
#   'Month': '/Date(1101877200000)/',
#   'MonthFormatted': '2004-12-01'},
#  {'Country': 0,
#   'InflationRate': 0.05238344683080147,
#   'InflationRateFormatted': '0.05',
#   'InflationRateRounded': 0.05,
#   'Month': '/Date(1099285200000)/',
#   'MonthFormatted': '2004-11-01'},
#  {'Country': 0,
#   'InflationRate': 0.526592943654555,
#   'InflationRateFormatted': '0.53',
#   'InflationRateRounded': 0.53,
#   'Month': '/Date(1096603200000)/',
#   'MonthFormatted': '2004-10-01'},
#  {'Country': 0,
#   'InflationRate': 0.21108179419525067,
#   'InflationRateFormatted': '0.21',
#   'InflationRateRounded': 0.21,
#   'Month': '/Date(1094011200000)/',
#   'MonthFormatted': '2004-09-01'},
#  {'Country': 0,
#   'InflationRate': 0.05279831045406547,
#   'InflationRateFormatted': '0.05',
#   'InflationRateRounded': 0.05,
#   'Month': '/Date(1091332800000)/',
#   'MonthFormatted': '2004-08-01'},
#  {'Country': 0,
#   'InflationRate': -0.158144438587243,
#   'InflationRateFormatted': '-0.16',
#   'InflationRateRounded': -0.16,
#   'Month': '/Date(1088654400000)/',
#   'MonthFormatted': '2004-07-01'},
#  {'Country': 0,
#   'InflationRate': 0.31729243786356426,
#   'InflationRateFormatted': '0.32',
#   'InflationRateRounded': 0.32,
#   'Month': '/Date(1086062400000)/',
#   'MonthFormatted': '2004-06-01'},
#  {'Country': 0,
#   'InflationRate': 0.5851063829787234,
#   'InflationRateFormatted': '0.59',
#   'InflationRateRounded': 0.59,
#   'Month': '/Date(1083384000000)/',
#   'MonthFormatted': '2004-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.32017075773745995,
#   'InflationRateFormatted': '0.32',
#   'InflationRateRounded': 0.32,
#   'Month': '/Date(1080795600000)/',
#   'MonthFormatted': '2004-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.644468313641246,
#   'InflationRateFormatted': '0.64',
#   'InflationRateRounded': 0.64,
#   'Month': '/Date(1078117200000)/',
#   'MonthFormatted': '2004-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.5399568034557235,
#   'InflationRateFormatted': '0.54',
#   'InflationRateRounded': 0.54,
#   'Month': '/Date(1075611600000)/',
#   'MonthFormatted': '2004-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.48833423765599565,
#   'InflationRateFormatted': '0.49',
#   'InflationRateRounded': 0.49,
#   'Month': '/Date(1072933200000)/',
#   'MonthFormatted': '2004-01-01'},
#  {'Country': 0,
#   'InflationRate': -0.10840108401084012,
#   'InflationRateFormatted': '-0.11',
#   'InflationRateRounded': -0.11,
#   'Month': '/Date(1070254800000)/',
#   'MonthFormatted': '2003-12-01'},
#  {'Country': 0,
#   'InflationRate': -0.2702702702702703,
#   'InflationRateFormatted': '-0.27',
#   'InflationRateRounded': -0.27,
#   'Month': '/Date(1067662800000)/',
#   'MonthFormatted': '2003-11-01'},
#  {'Country': 0,
#   'InflationRate': -0.1079913606911447,
#   'InflationRateFormatted': '-0.11',
#   'InflationRateRounded': -0.11,
#   'Month': '/Date(1064980800000)/',
#   'MonthFormatted': '2003-10-01'},
#  {'Country': 0,
#   'InflationRate': 0.3250270855904659,
#   'InflationRateFormatted': '0.33',
#   'InflationRateRounded': 0.33,
#   'Month': '/Date(1062388800000)/',
#   'MonthFormatted': '2003-09-01'},
#  {'Country': 0,
#   'InflationRate': 0.3806416530723219,
#   'InflationRateFormatted': '0.38',
#   'InflationRateRounded': 0.38,
#   'Month': '/Date(1059710400000)/',
#   'MonthFormatted': '2003-08-01'},
#  {'Country': 0,
#   'InflationRate': 0.10887316276537834,
#   'InflationRateFormatted': '0.11',
#   'InflationRateRounded': 0.11,
#   'Month': '/Date(1057032000000)/',
#   'MonthFormatted': '2003-07-01'},
#  {'Country': 0,
#   'InflationRate': 0.10899182561307902,
#   'InflationRateFormatted': '0.11',
#   'InflationRateRounded': 0.11,
#   'Month': '/Date(1054440000000)/',
#   'MonthFormatted': '2003-06-01'},
#  {'Country': 0,
#   'InflationRate': -0.1632208922742111,
#   'InflationRateFormatted': '-0.16',
#   'InflationRateRounded': -0.16,
#   'Month': '/Date(1051761600000)/',
#   'MonthFormatted': '2003-05-01'},
#  {'Country': 0,
#   'InflationRate': -0.21715526601520088,
#   'InflationRateFormatted': '-0.22',
#   'InflationRateRounded': -0.22,
#   'Month': '/Date(1049173200000)/',
#   'MonthFormatted': '2003-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.6007646095030038,
#   'InflationRateFormatted': '0.60',
#   'InflationRateRounded': 0.6,
#   'Month': '/Date(1046494800000)/',
#   'MonthFormatted': '2003-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.7705008255365988,
#   'InflationRateFormatted': '0.77',
#   'InflationRateRounded': 0.77,
#   'Month': '/Date(1044075600000)/',
#   'MonthFormatted': '2003-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.44223327805417356,
#   'InflationRateFormatted': '0.44',
#   'InflationRateRounded': 0.44,
#   'Month': '/Date(1041397200000)/',
#   'MonthFormatted': '2003-01-01'},
#  {'Country': 0,
#   'InflationRate': -0.2206287920573635,
#   'InflationRateFormatted': '-0.22',
#   'InflationRateRounded': -0.22,
#   'Month': '/Date(1038718800000)/',
#   'MonthFormatted': '2002-12-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(1036126800000)/',
#   'MonthFormatted': '2002-11-01'},
#  {'Country': 0,
#   'InflationRate': 0.16574585635359115,
#   'InflationRateFormatted': '0.17',
#   'InflationRateRounded': 0.17,
#   'Month': '/Date(1033444800000)/',
#   'MonthFormatted': '2002-10-01'},
#  {'Country': 0,
#   'InflationRate': 0.16602102933038185,
#   'InflationRateFormatted': '0.17',
#   'InflationRateRounded': 0.17,
#   'Month': '/Date(1030852800000)/',
#   'MonthFormatted': '2002-09-01'},
#  {'Country': 0,
#   'InflationRate': 0.3331482509716824,
#   'InflationRateFormatted': '0.33',
#   'InflationRateRounded': 0.33,
#   'Month': '/Date(1028174400000)/',
#   'MonthFormatted': '2002-08-01'},
#  {'Country': 0,
#   'InflationRate': 0.11117287381878821,
#   'InflationRateFormatted': '0.11',
#   'InflationRateRounded': 0.11,
#   'Month': '/Date(1025496000000)/',
#   'MonthFormatted': '2002-07-01'},
#  {'Country': 0,
#   'InflationRate': 0.05561735261401557,
#   'InflationRateFormatted': '0.06',
#   'InflationRateRounded': 0.06,
#   'Month': '/Date(1022904000000)/',
#   'MonthFormatted': '2002-06-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(1020225600000)/',
#   'MonthFormatted': '2002-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.5592841163310962,
#   'InflationRateFormatted': '0.56',
#   'InflationRateRounded': 0.56,
#   'Month': '/Date(1017637200000)/',
#   'MonthFormatted': '2002-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.562429696287964,
#   'InflationRateFormatted': '0.56',
#   'InflationRateRounded': 0.56,
#   'Month': '/Date(1014958800000)/',
#   'MonthFormatted': '2002-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.3952569169960474,
#   'InflationRateFormatted': '0.40',
#   'InflationRateRounded': 0.4,
#   'Month': '/Date(1012539600000)/',
#   'MonthFormatted': '2002-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.22637238256932654,
#   'InflationRateFormatted': '0.23',
#   'InflationRateRounded': 0.23,
#   'Month': '/Date(1009861200000)/',
#   'MonthFormatted': '2002-01-01'},
#  {'Country': 0,
#   'InflationRate': -0.3945885005636979,
#   'InflationRateFormatted': '-0.39',
#   'InflationRateRounded': -0.39,
#   'Month': '/Date(1007182800000)/',
#   'MonthFormatted': '2001-12-01'},
#  {'Country': 0,
#   'InflationRate': -0.16882386043894204,
#   'InflationRateFormatted': '-0.17',
#   'InflationRateRounded': -0.17,
#   'Month': '/Date(1004590800000)/',
#   'MonthFormatted': '2001-11-01'},
#  {'Country': 0,
#   'InflationRate': -0.33651149747616377,
#   'InflationRateFormatted': '-0.34',
#   'InflationRateRounded': -0.34,
#   'Month': '/Date(1001908800000)/',
#   'MonthFormatted': '2001-10-01'},
#  {'Country': 0,
#   'InflationRate': 0.4507042253521127,
#   'InflationRateFormatted': '0.45',
#   'InflationRateRounded': 0.45,
#   'Month': '/Date(999316800000)/',
#   'MonthFormatted': '2001-09-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(996638400000)/',
#   'MonthFormatted': '2001-08-01'},
#  {'Country': 0,
#   'InflationRate': -0.2808988764044944,
#   'InflationRateFormatted': '-0.28',
#   'InflationRateRounded': -0.28,
#   'Month': '/Date(993960000000)/',
#   'MonthFormatted': '2001-07-01'},
#  {'Country': 0,
#   'InflationRate': 0.16882386043894204,
#   'InflationRateFormatted': '0.17',
#   'InflationRateRounded': 0.17,
#   'Month': '/Date(991368000000)/',
#   'MonthFormatted': '2001-06-01'},
#  {'Country': 0,
#   'InflationRate': 0.4522328999434709,
#   'InflationRateFormatted': '0.45',
#   'InflationRateRounded': 0.45,
#   'Month': '/Date(988689600000)/',
#   'MonthFormatted': '2001-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.39727582292849034,
#   'InflationRateFormatted': '0.40',
#   'InflationRateRounded': 0.4,
#   'Month': '/Date(986101200000)/',
#   'MonthFormatted': '2001-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.22753128555176336,
#   'InflationRateFormatted': '0.23',
#   'InflationRateRounded': 0.23,
#   'Month': '/Date(983422800000)/',
#   'MonthFormatted': '2001-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.3997715591090805,
#   'InflationRateFormatted': '0.40',
#   'InflationRateRounded': 0.4,
#   'Month': '/Date(981003600000)/',
#   'MonthFormatted': '2001-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.632183908045977,
#   'InflationRateFormatted': '0.63',
#   'InflationRateRounded': 0.63,
#   'Month': '/Date(978325200000)/',
#   'MonthFormatted': '2001-01-01'},
#  {'Country': 0,
#   'InflationRate': -0.05743825387708214,
#   'InflationRateFormatted': '-0.06',
#   'InflationRateRounded': -0.06,
#   'Month': '/Date(975646800000)/',
#   'MonthFormatted': '2000-12-01'},
#  {'Country': 0,
#   'InflationRate': 0.05747126436781609,
#   'InflationRateFormatted': '0.06',
#   'InflationRateRounded': 0.06,
#   'Month': '/Date(973054800000)/',
#   'MonthFormatted': '2000-11-01'},
#  {'Country': 0,
#   'InflationRate': 0.17271157167530224,
#   'InflationRateFormatted': '0.17',
#   'InflationRateRounded': 0.17,
#   'Month': '/Date(970372800000)/',
#   'MonthFormatted': '2000-10-01'},
#  {'Country': 0,
#   'InflationRate': 0.5208333333333334,
#   'InflationRateFormatted': '0.52',
#   'InflationRateRounded': 0.52,
#   'Month': '/Date(967780800000)/',
#   'MonthFormatted': '2000-09-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(965102400000)/',
#   'MonthFormatted': '2000-08-01'},
#  {'Country': 0,
#   'InflationRate': 0.23201856148491878,
#   'InflationRateFormatted': '0.23',
#   'InflationRateRounded': 0.23,
#   'Month': '/Date(962424000000)/',
#   'MonthFormatted': '2000-07-01'},
#  {'Country': 0,
#   'InflationRate': 0.5247813411078717,
#   'InflationRateFormatted': '0.52',
#   'InflationRateRounded': 0.52,
#   'Month': '/Date(959832000000)/',
#   'MonthFormatted': '2000-06-01'},
#  {'Country': 0,
#   'InflationRate': 0.11675423234092236,
#   'InflationRateFormatted': '0.12',
#   'InflationRateRounded': 0.12,
#   'Month': '/Date(957153600000)/',
#   'MonthFormatted': '2000-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.05841121495327103,
#   'InflationRateFormatted': '0.06',
#   'InflationRateRounded': 0.06,
#   'Month': '/Date(954565200000)/',
#   'MonthFormatted': '2000-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.8244994110718492,
#   'InflationRateFormatted': '0.82',
#   'InflationRateRounded': 0.82,
#   'Month': '/Date(951886800000)/',
#   'MonthFormatted': '2000-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.5924170616113744,
#   'InflationRateFormatted': '0.59',
#   'InflationRateRounded': 0.59,
#   'Month': '/Date(949381200000)/',
#   'MonthFormatted': '2000-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.29708853238265004,
#   'InflationRateFormatted': '0.30',
#   'InflationRateRounded': 0.3,
#   'Month': '/Date(946702800000)/',
#   'MonthFormatted': '2000-01-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(944024400000)/',
#   'MonthFormatted': '1999-12-01'},
#  {'Country': 0,
#   'InflationRate': 0.059453032104637336,
#   'InflationRateFormatted': '0.06',
#   'InflationRateRounded': 0.06,
#   'Month': '/Date(941432400000)/',
#   'MonthFormatted': '1999-11-01'},
#  {'Country': 0,
#   'InflationRate': 0.1786777843954735,
#   'InflationRateFormatted': '0.18',
#   'InflationRateRounded': 0.18,
#   'Month': '/Date(938750400000)/',
#   'MonthFormatted': '1999-10-01'},
#  {'Country': 0,
#   'InflationRate': 0.47875523638539796,
#   'InflationRateFormatted': '0.48',
#   'InflationRateRounded': 0.48,
#   'Month': '/Date(936158400000)/',
#   'MonthFormatted': '1999-09-01'},
#  {'Country': 0,
#   'InflationRate': 0.23995200959808038,
#   'InflationRateFormatted': '0.24',
#   'InflationRateRounded': 0.24,
#   'Month': '/Date(933480000000)/',
#   'MonthFormatted': '1999-08-01'},
#  {'Country': 0,
#   'InflationRate': 0.3008423586040915,
#   'InflationRateFormatted': '0.30',
#   'InflationRateRounded': 0.3,
#   'Month': '/Date(930801600000)/',
#   'MonthFormatted': '1999-07-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(928209600000)/',
#   'MonthFormatted': '1999-06-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(925531200000)/',
#   'MonthFormatted': '1999-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.7272727272727273,
#   'InflationRateFormatted': '0.73',
#   'InflationRateRounded': 0.73,
#   'Month': '/Date(922942800000)/',
#   'MonthFormatted': '1999-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.303951367781155,
#   'InflationRateFormatted': '0.30',
#   'InflationRateRounded': 0.3,
#   'Month': '/Date(920264400000)/',
#   'MonthFormatted': '1999-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.12172854534388314,
#   'InflationRateFormatted': '0.12',
#   'InflationRateRounded': 0.12,
#   'Month': '/Date(917845200000)/',
#   'MonthFormatted': '1999-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.24405125076266015,
#   'InflationRateFormatted': '0.24',
#   'InflationRateRounded': 0.24,
#   'Month': '/Date(915166800000)/',
#   'MonthFormatted': '1999-01-01'},
#  {'Country': 0,
#   'InflationRate': -0.06097560975609756,
#   'InflationRateFormatted': '-0.06',
#   'InflationRateRounded': -0.06,
#   'Month': '/Date(912488400000)/',
#   'MonthFormatted': '1998-12-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(909896400000)/',
#   'MonthFormatted': '1998-11-01'},
#  {'Country': 0,
#   'InflationRate': 0.24449877750611246,
#   'InflationRateFormatted': '0.24',
#   'InflationRateRounded': 0.24,
#   'Month': '/Date(907214400000)/',
#   'MonthFormatted': '1998-10-01'},
#  {'Country': 0,
#   'InflationRate': 0.12239902080783353,
#   'InflationRateFormatted': '0.12',
#   'InflationRateRounded': 0.12,
#   'Month': '/Date(904622400000)/',
#   'MonthFormatted': '1998-09-01'},
#  {'Country': 0,
#   'InflationRate': 0.12254901960784313,
#   'InflationRateFormatted': '0.12',
#   'InflationRateRounded': 0.12,
#   'Month': '/Date(901944000000)/',
#   'MonthFormatted': '1998-08-01'},
#  {'Country': 0,
#   'InflationRate': 0.12269938650306748,
#   'InflationRateFormatted': '0.12',
#   'InflationRateRounded': 0.12,
#   'Month': '/Date(899265600000)/',
#   'MonthFormatted': '1998-07-01'},
#  {'Country': 0,
#   'InflationRate': 0.12285012285012285,
#   'InflationRateFormatted': '0.12',
#   'InflationRateRounded': 0.12,
#   'Month': '/Date(896673600000)/',
#   'MonthFormatted': '1998-06-01'},
#  {'Country': 0,
#   'InflationRate': 0.18461538461538463,
#   'InflationRateFormatted': '0.18',
#   'InflationRateRounded': 0.18,
#   'Month': '/Date(893995200000)/',
#   'MonthFormatted': '1998-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.18495684340320592,
#   'InflationRateFormatted': '0.18',
#   'InflationRateRounded': 0.18,
#   'Month': '/Date(891406800000)/',
#   'MonthFormatted': '1998-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.1852995676343422,
#   'InflationRateFormatted': '0.19',
#   'InflationRateRounded': 0.19,
#   'Month': '/Date(888728400000)/',
#   'MonthFormatted': '1998-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.18564356435643564,
#   'InflationRateFormatted': '0.19',
#   'InflationRateRounded': 0.19,
#   'Month': '/Date(886309200000)/',
#   'MonthFormatted': '1998-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.1859888406695598,
#   'InflationRateFormatted': '0.19',
#   'InflationRateRounded': 0.19,
#   'Month': '/Date(883630800000)/',
#   'MonthFormatted': '1998-01-01'},
#  {'Country': 0,
#   'InflationRate': -0.1238390092879257,
#   'InflationRateFormatted': '-0.12',
#   'InflationRateRounded': -0.12,
#   'Month': '/Date(880952400000)/',
#   'MonthFormatted': '1997-12-01'},
#  {'Country': 0,
#   'InflationRate': -0.06188118811881188,
#   'InflationRateFormatted': '-0.06',
#   'InflationRateRounded': -0.06,
#   'Month': '/Date(878360400000)/',
#   'MonthFormatted': '1997-11-01'},
#  {'Country': 0,
#   'InflationRate': 0.24813895781637718,
#   'InflationRateFormatted': '0.25',
#   'InflationRateRounded': 0.25,
#   'Month': '/Date(875678400000)/',
#   'MonthFormatted': '1997-10-01'},
#  {'Country': 0,
#   'InflationRate': 0.24875621890547264,
#   'InflationRateFormatted': '0.25',
#   'InflationRateRounded': 0.25,
#   'Month': '/Date(873086400000)/',
#   'MonthFormatted': '1997-09-01'},
#  {'Country': 0,
#   'InflationRate': 0.18691588785046728,
#   'InflationRateFormatted': '0.19',
#   'InflationRateRounded': 0.19,
#   'Month': '/Date(870408000000)/',
#   'MonthFormatted': '1997-08-01'},
#  {'Country': 0,
#   'InflationRate': 0.12476606363069245,
#   'InflationRateFormatted': '0.12',
#   'InflationRateRounded': 0.12,
#   'Month': '/Date(867729600000)/',
#   'MonthFormatted': '1997-07-01'},
#  {'Country': 0,
#   'InflationRate': 0.12492192379762648,
#   'InflationRateFormatted': '0.12',
#   'InflationRateRounded': 0.12,
#   'Month': '/Date(865137600000)/',
#   'MonthFormatted': '1997-06-01'},
#  {'Country': 0,
#   'InflationRate': -0.062421972534332085,
#   'InflationRateFormatted': '-0.06',
#   'InflationRateRounded': -0.06,
#   'Month': '/Date(862459200000)/',
#   'MonthFormatted': '1997-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.125,
#   'InflationRateFormatted': '0.13',
#   'InflationRateRounded': 0.12,
#   'Month': '/Date(859870800000)/',
#   'MonthFormatted': '1997-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.2506265664160401,
#   'InflationRateFormatted': '0.25',
#   'InflationRateRounded': 0.25,
#   'Month': '/Date(857192400000)/',
#   'MonthFormatted': '1997-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.3142677561282212,
#   'InflationRateFormatted': '0.31',
#   'InflationRateRounded': 0.31,
#   'Month': '/Date(854773200000)/',
#   'MonthFormatted': '1997-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.31525851197982346,
#   'InflationRateFormatted': '0.32',
#   'InflationRateRounded': 0.32,
#   'Month': '/Date(852094800000)/',
#   'MonthFormatted': '1997-01-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(849416400000)/',
#   'MonthFormatted': '1996-12-01'},
#  {'Country': 0,
#   'InflationRate': 0.18951358180669614,
#   'InflationRateFormatted': '0.19',
#   'InflationRateRounded': 0.19,
#   'Month': '/Date(846824400000)/',
#   'MonthFormatted': '1996-11-01'},
#  {'Country': 0,
#   'InflationRate': 0.31685678073510776,
#   'InflationRateFormatted': '0.32',
#   'InflationRateRounded': 0.32,
#   'Month': '/Date(844142400000)/',
#   'MonthFormatted': '1996-10-01'},
#  {'Country': 0,
#   'InflationRate': 0.3178639542275906,
#   'InflationRateFormatted': '0.32',
#   'InflationRateRounded': 0.32,
#   'Month': '/Date(841550400000)/',
#   'MonthFormatted': '1996-09-01'},
#  {'Country': 0,
#   'InflationRate': 0.1910828025477707,
#   'InflationRateFormatted': '0.19',
#   'InflationRateRounded': 0.19,
#   'Month': '/Date(838872000000)/',
#   'MonthFormatted': '1996-08-01'},
#  {'Country': 0,
#   'InflationRate': 0.1914486279514997,
#   'InflationRateFormatted': '0.19',
#   'InflationRateRounded': 0.19,
#   'Month': '/Date(836193600000)/',
#   'MonthFormatted': '1996-07-01'},
#  {'Country': 0,
#   'InflationRate': 0.06385696040868455,
#   'InflationRateFormatted': '0.06',
#   'InflationRateRounded': 0.06,
#   'Month': '/Date(833601600000)/',
#   'MonthFormatted': '1996-06-01'},
#  {'Country': 0,
#   'InflationRate': 0.19193857965451055,
#   'InflationRateFormatted': '0.19',
#   'InflationRateRounded': 0.19,
#   'Month': '/Date(830923200000)/',
#   'MonthFormatted': '1996-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.3853564547206166,
#   'InflationRateFormatted': '0.39',
#   'InflationRateRounded': 0.39,
#   'Month': '/Date(828334800000)/',
#   'MonthFormatted': '1996-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.5164622336991608,
#   'InflationRateFormatted': '0.52',
#   'InflationRateRounded': 0.52,
#   'Month': '/Date(825656400000)/',
#   'MonthFormatted': '1996-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.3238341968911917,
#   'InflationRateFormatted': '0.32',
#   'InflationRateRounded': 0.32,
#   'Month': '/Date(823150800000)/',
#   'MonthFormatted': '1996-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.5863192182410424,
#   'InflationRateFormatted': '0.59',
#   'InflationRateRounded': 0.59,
#   'Month': '/Date(820472400000)/',
#   'MonthFormatted': '1996-01-01'},
#  {'Country': 0,
#   'InflationRate': -0.06510416666666667,
# ...
#  {'Country': 0,
#   'InflationRate': 0.7142857142857143,
#   'InflationRateFormatted': '0.71',
#   'InflationRateRounded': 0.71,
#   'Month': '/Date(-933624000000)/',
#   'MonthFormatted': '1940-06-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-936302400000)/',
#   'MonthFormatted': '1940-05-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-938890800000)/',
#   'MonthFormatted': '1940-04-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-941569200000)/',
#   'MonthFormatted': '1940-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.7194244604316546,
#   'InflationRateFormatted': '0.72',
#   'InflationRateRounded': 0.72,
#   'Month': '/Date(-944074800000)/',
#   'MonthFormatted': '1940-02-01'},
#  {'Country': 0,
#   'InflationRate': -0.7142857142857143,
#   'InflationRateFormatted': '-0.71',
#   'InflationRateRounded': -0.71,
#   'Month': '/Date(-946753200000)/',
#   'MonthFormatted': '1940-01-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-949431600000)/',
#   'MonthFormatted': '1939-12-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-952023600000)/',
#   'MonthFormatted': '1939-11-01'},
#  {'Country': 0,
#   'InflationRate': -0.7092198581560284,
#   'InflationRateFormatted': '-0.71',
#   'InflationRateRounded': -0.71,
#   'Month': '/Date(-954705600000)/',
#   'MonthFormatted': '1939-10-01'},
#  {'Country': 0,
#   'InflationRate': 2.1739130434782608,
#   'InflationRateFormatted': '2.17',
#   'InflationRateRounded': 2.17,
#   'Month': '/Date(-957297600000)/',
#   'MonthFormatted': '1939-09-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-959976000000)/',
#   'MonthFormatted': '1939-08-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-962654400000)/',
#   'MonthFormatted': '1939-07-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-965246400000)/',
#   'MonthFormatted': '1939-06-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-967924800000)/',
#   'MonthFormatted': '1939-05-01'},
#  {'Country': 0,
#   'InflationRate': -0.7194244604316546,
#   'InflationRateFormatted': '-0.72',
#   'InflationRateRounded': -0.72,
#   'Month': '/Date(-970513200000)/',
#   'MonthFormatted': '1939-04-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-973191600000)/',
#   'MonthFormatted': '1939-03-01'},
#  {'Country': 0,
#   'InflationRate': -0.7142857142857143,
#   'InflationRateFormatted': '-0.71',
#   'InflationRateRounded': -0.71,
#   'Month': '/Date(-975610800000)/',
#   'MonthFormatted': '1939-02-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-978289200000)/',
#   'MonthFormatted': '1939-01-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-980967600000)/',
#   'MonthFormatted': '1938-12-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-983559600000)/',
#   'MonthFormatted': '1938-11-01'},
#  {'Country': 0,
#   'InflationRate': -0.7092198581560284,
#   'InflationRateFormatted': '-0.71',
#   'InflationRateRounded': -0.71,
#   'Month': '/Date(-986241600000)/',
#   'MonthFormatted': '1938-10-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-988833600000)/',
#   'MonthFormatted': '1938-09-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-991512000000)/',
#   'MonthFormatted': '1938-08-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-994190400000)/',
#   'MonthFormatted': '1938-07-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-996782400000)/',
#   'MonthFormatted': '1938-06-01'},
#  {'Country': 0,
#   'InflationRate': -0.704225352112676,
#   'InflationRateFormatted': '-0.70',
#   'InflationRateRounded': -0.7,
#   'Month': '/Date(-999460800000)/',
#   'MonthFormatted': '1938-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.7092198581560284,
#   'InflationRateFormatted': '0.71',
#   'InflationRateRounded': 0.71,
#   'Month': '/Date(-1002049200000)/',
#   'MonthFormatted': '1938-04-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1004727600000)/',
#   'MonthFormatted': '1938-03-01'},
#  {'Country': 0,
#   'InflationRate': -0.704225352112676,
#   'InflationRateFormatted': '-0.70',
#   'InflationRateRounded': -0.7,
#   'Month': '/Date(-1007146800000)/',
#   'MonthFormatted': '1938-02-01'},
#  {'Country': 0,
#   'InflationRate': -1.3888888888888888,
#   'InflationRateFormatted': '-1.39',
#   'InflationRateRounded': -1.39,
#   'Month': '/Date(-1009825200000)/',
#   'MonthFormatted': '1938-01-01'},
#  {'Country': 0,
#   'InflationRate': -0.6896551724137931,
#   'InflationRateFormatted': '-0.69',
#   'InflationRateRounded': -0.69,
#   'Month': '/Date(-1012503600000)/',
#   'MonthFormatted': '1937-12-01'},
#  {'Country': 0,
#   'InflationRate': -0.684931506849315,
#   'InflationRateFormatted': '-0.68',
#   'InflationRateRounded': -0.68,
#   'Month': '/Date(-1015095600000)/',
#   'MonthFormatted': '1937-11-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1017777600000)/',
#   'MonthFormatted': '1937-10-01'},
#  {'Country': 0,
#   'InflationRate': 0.6896551724137931,
#   'InflationRateFormatted': '0.69',
#   'InflationRateRounded': 0.69,
#   'Month': '/Date(-1020369600000)/',
#   'MonthFormatted': '1937-09-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1023048000000)/',
#   'MonthFormatted': '1937-08-01'},
#  {'Country': 0,
#   'InflationRate': 0.6944444444444444,
#   'InflationRateFormatted': '0.69',
#   'InflationRateRounded': 0.69,
#   'Month': '/Date(-1025726400000)/',
#   'MonthFormatted': '1937-07-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1028318400000)/',
#   'MonthFormatted': '1937-06-01'},
#  {'Country': 0,
#   'InflationRate': 0.6993006993006993,
#   'InflationRateFormatted': '0.70',
#   'InflationRateRounded': 0.7,
#   'Month': '/Date(-1030996800000)/',
#   'MonthFormatted': '1937-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.704225352112676,
#   'InflationRateFormatted': '0.70',
#   'InflationRateRounded': 0.7,
#   'Month': '/Date(-1033585200000)/',
#   'MonthFormatted': '1937-04-01'},
#  {'Country': 0,
#   'InflationRate': 0.7092198581560284,
#   'InflationRateFormatted': '0.71',
#   'InflationRateRounded': 0.71,
#   'Month': '/Date(-1036263600000)/',
#   'MonthFormatted': '1937-03-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1038682800000)/',
#   'MonthFormatted': '1937-02-01'},
#  {'Country': 0,
#   'InflationRate': 0.7142857142857143,
#   'InflationRateFormatted': '0.71',
#   'InflationRateRounded': 0.71,
#   'Month': '/Date(-1041361200000)/',
#   'MonthFormatted': '1937-01-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1044039600000)/',
#   'MonthFormatted': '1936-12-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1046631600000)/',
#   'MonthFormatted': '1936-11-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1049313600000)/',
#   'MonthFormatted': '1936-10-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1051905600000)/',
#   'MonthFormatted': '1936-09-01'},
#  {'Country': 0,
#   'InflationRate': 0.7194244604316546,
#   'InflationRateFormatted': '0.72',
#   'InflationRateRounded': 0.72,
#   'Month': '/Date(-1054584000000)/',
#   'MonthFormatted': '1936-08-01'},
#  {'Country': 0,
#   'InflationRate': 0.7246376811594203,
#   'InflationRateFormatted': '0.72',
#   'InflationRateRounded': 0.72,
#   'Month': '/Date(-1057262400000)/',
#   'MonthFormatted': '1936-07-01'},
#  {'Country': 0,
#   'InflationRate': 0.7299270072992701,
#   'InflationRateFormatted': '0.73',
#   'InflationRateRounded': 0.73,
#   'Month': '/Date(-1059854400000)/',
#   'MonthFormatted': '1936-06-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1062532800000)/',
#   'MonthFormatted': '1936-05-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1065121200000)/',
#   'MonthFormatted': '1936-04-01'},
#  {'Country': 0,
#   'InflationRate': -0.7246376811594203,
#   'InflationRateFormatted': '-0.72',
#   'InflationRateRounded': -0.72,
#   'Month': '/Date(-1067799600000)/',
#   'MonthFormatted': '1936-03-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1070305200000)/',
#   'MonthFormatted': '1936-02-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1072983600000)/',
#   'MonthFormatted': '1936-01-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1075662000000)/',
#   'MonthFormatted': '1935-12-01'},
#  {'Country': 0,
#   'InflationRate': 0.7299270072992701,
#   'InflationRateFormatted': '0.73',
#   'InflationRateRounded': 0.73,
#   'Month': '/Date(-1078254000000)/',
#   'MonthFormatted': '1935-11-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1080936000000)/',
#   'MonthFormatted': '1935-10-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1083528000000)/',
#   'MonthFormatted': '1935-09-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1086206400000)/',
#   'MonthFormatted': '1935-08-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1088884800000)/',
#   'MonthFormatted': '1935-07-01'},
#  {'Country': 0,
#   'InflationRate': -0.7246376811594203,
#   'InflationRateFormatted': '-0.72',
#   'InflationRateRounded': -0.72,
#   'Month': '/Date(-1091476800000)/',
#   'MonthFormatted': '1935-06-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1094155200000)/',
#   'MonthFormatted': '1935-05-01'},
#  {'Country': 0,
#   'InflationRate': 0.7299270072992701,
#   'InflationRateFormatted': '0.73',
#   'InflationRateRounded': 0.73,
#   'Month': '/Date(-1096743600000)/',
#   'MonthFormatted': '1935-04-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1099422000000)/',
#   'MonthFormatted': '1935-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.7352941176470589,
#   'InflationRateFormatted': '0.74',
#   'InflationRateRounded': 0.74,
#   'Month': '/Date(-1101841200000)/',
#   'MonthFormatted': '1935-02-01'},
#  {'Country': 0,
#   'InflationRate': 1.492537313432836,
#   'InflationRateFormatted': '1.49',
#   'InflationRateRounded': 1.49,
#   'Month': '/Date(-1104519600000)/',
#   'MonthFormatted': '1935-01-01'},
#  {'Country': 0,
#   'InflationRate': -0.7407407407407407,
#   'InflationRateFormatted': '-0.74',
#   'InflationRateRounded': -0.74,
#   'Month': '/Date(-1107198000000)/',
#   'MonthFormatted': '1934-12-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1109790000000)/',
#   'MonthFormatted': '1934-11-01'},
#  {'Country': 0,
#   'InflationRate': -0.7352941176470589,
#   'InflationRateFormatted': '-0.74',
#   'InflationRateRounded': -0.74,
#   'Month': '/Date(-1112472000000)/',
#   'MonthFormatted': '1934-10-01'},
#  {'Country': 0,
#   'InflationRate': 1.492537313432836,
#   'InflationRateFormatted': '1.49',
#   'InflationRateRounded': 1.49,
#   'Month': '/Date(-1115064000000)/',
#   'MonthFormatted': '1934-09-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1117742400000)/',
#   'MonthFormatted': '1934-08-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1120420800000)/',
#   'MonthFormatted': '1934-07-01'},
#  {'Country': 0,
#   'InflationRate': 0.7518796992481203,
#   'InflationRateFormatted': '0.75',
#   'InflationRateRounded': 0.75,
#   'Month': '/Date(-1123012800000)/',
#   'MonthFormatted': '1934-06-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1125691200000)/',
#   'MonthFormatted': '1934-05-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1128279600000)/',
#   'MonthFormatted': '1934-04-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1130958000000)/',
#   'MonthFormatted': '1934-03-01'},
#  {'Country': 0,
#   'InflationRate': 0.7575757575757576,
#   'InflationRateFormatted': '0.76',
#   'InflationRateRounded': 0.76,
#   'Month': '/Date(-1133377200000)/',
#   'MonthFormatted': '1934-02-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1136055600000)/',
#   'MonthFormatted': '1934-01-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1138734000000)/',
#   'MonthFormatted': '1933-12-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1141326000000)/',
#   'MonthFormatted': '1933-11-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1144008000000)/',
#   'MonthFormatted': '1933-10-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1146600000000)/',
#   'MonthFormatted': '1933-09-01'},
#  {'Country': 0,
#   'InflationRate': 0.7633587786259542,
#   'InflationRateFormatted': '0.76',
#   'InflationRateRounded': 0.76,
#   'Month': '/Date(-1149278400000)/',
#   'MonthFormatted': '1933-08-01'},
#  {'Country': 0,
#   'InflationRate': 3.1496062992125986,
#   'InflationRateFormatted': '3.15',
#   'InflationRateRounded': 3.15,
#   'Month': '/Date(-1151956800000)/',
#   'MonthFormatted': '1933-07-01'},
#  {'Country': 0,
#   'InflationRate': 0.7936507936507936,
#   'InflationRateFormatted': '0.79',
#   'InflationRateRounded': 0.79,
#   'Month': '/Date(-1154548800000)/',
#   'MonthFormatted': '1933-06-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1157227200000)/',
#   'MonthFormatted': '1933-05-01'},
#  {'Country': 0,
#   'InflationRate': 0,
#   'InflationRateFormatted': '0.00',
#   'InflationRateRounded': 0,
#   'Month': '/Date(-1159815600000)/',
#   'MonthFormatted': '1933-04-01'},
#  ...]

# %%
inflation = json.loads(r.text)

# %%
inflation[-1]
# Out:
# {'Country': 0,
#  'InflationRate': 0,
#  'InflationRateFormatted': '0.00',
#  'InflationRateRounded': 0,
#  'Month': '/Date(-1796065200000)/',
#  'MonthFormatted': '1913-02-01'}

# %%
y = json.loads(x)
type(y)
# Out:
# dict

# %%
adjusted = requests.get("https://www.statbureau.org/calculate-inflation-price-json?country=united-states&start=1954/1/1&end=2016/8/1&amount=0.32")

# %%
adjusted.status_code
# Out:
# 200

# %%
type(adjusted.json())
# Out:
# str

# %%
import math
math.nan
# Out:
# nan

# %%
def get_adjusted_price(year, price):
    req_url = "https://www.statbureau.org/calculate-inflation-price-json?country=united-states&start={}/1/1&end=2016/8/1&amount={}"
    resp = requests.get(req_url.format(year,price))
    if resp.status_code == 200:
        adj_price = float(resp.json().replace('$','').replace(',','').replace(' ',''))
    else:
        adj_price = math.nan
    return adj_price

print(get_adjusted_price(1990,1.00))
# Out:
# 1.91

# %% [markdown]
# ### Don't work too hard
#
# Concatenating strings with ``+`` is hard and error prone.  Use the Python tools for formatted strings!

# %%
"hello %s  :::::: %d" % ('world', 324234)
# Out:
# 'hello world  :::::: 324234'

# %%
"hello {} :::: {}".format('world', 123123123)
# Out:
# 'hello world :::: 123123123'

# %% [markdown]
# ## Now lets get the Box office data

# %%
page = requests.get('http://www.the-numbers.com/movie/records/All-Time-Domestic-Box-Office')
soup = BeautifulSoup(page.text,"lxml")

# %%
def unformat_money(s):
    '''
    take a string that is formatted as dollars, and return a float or int

    '''
    news = s.replace('$','').replace(',','')
    if "." in news:
        return float(news)
    else:
        return int(news)

# %%
d = {'year':[], 'title':[], 'domestic':[] ,'international':[], 'worldwide':[]}
rows = soup.find_all('tr')
for row in rows[1:]:
    row_data = row.find_all('td')
    d['year'].append(int(row_data[1].text))
    d['title'].append(row_data[2].find('a').text)
    d['domestic'].append(unformat_money(row_data[3].text))
    d['international'].append(unformat_money(row_data[4].text))
    d['worldwide'].append(unformat_money(row_data[5].text))

# %%
df = pd.DataFrame(d)
df.head()
# Out:
#     domestic  international                                 title   worldwide  \
# 0  936662225     1122000000  Star Wars Ep. VII: The Force Awakens  2058662225
# 1  760507625     2023411357                                Avatar  2783918982
# 2  658672302     1548943366                               Titanic  2207615668
# 3  652198010     1018130015                        Jurassic World  1670328025
# 4  623279547      896200000                          The Avengers  1519479547
#
#    year
# 0  2015
# 1  2009
# 2  1997
# 3  2015
# 4  2012

# %% [markdown]
# Ok, the function we wrote above won't work perfectly for us because we want to use the ``apply`` method to automatically iterate over each row of the dataframe and we want to extract the year and domestic price from each row.  apply expects to get a function that takes a SINGLE parameter not TWO.  The single parameter corresponds to a row or a column depending on the value of the axis parameter.  So our wrapper will have to unpack the row and call the ``get_adjusted_price`` function, and simply pass on the return value.

# %%
def wrapper(the_row):
    return get_adjusted_price(the_row.year, the_row.domestic)

df['adj_domestic'] = df.apply(wrapper, axis=1)

# %%
df.head()
# Out:
#     domestic  international                                 title   worldwide  \
# 0  936662225     1122000000  Star Wars Ep. VII: The Force Awakens  2058662225
# 1  760507625     2023411357                                Avatar  2783918982
# 2  658672302     1548943366                               Titanic  2207615668
# 3  652198010     1018130015                        Jurassic World  1670328025
# 4  623279547      896200000                          The Avengers  1519479547
#
#    year  adj_domestic
# 0  2015  9.599380e+08
# 1  2009  8.705495e+08
# 2  1997  9.994169e+08
# 3  2015  6.684049e+08
# 4  2012  6.646387e+08

# %%
df.sort_values(by=['adj_domestic'],ascending=False)
# Out:
#      domestic  international                                          title  \
# 8   460998007      325600000                   Star Wars Ep. IV: A New Hope
# 89  260000000      210700000                                           Jaws
# 12  435110554      357854772                      ET: The Extra-Terrestrial
# 2   658672302     1548943366                                        Titanic
# 0   936662225     1122000000           Star Wars Ep. VII: The Force Awakens
# 73  290271960      243900000       Star Wars Ep. V: The Empire Strikes Back
# 1   760507625     2023411357                                         Avatar
# 56  309205079      263500000           Star Wars Ep. VI: Return of the Jedi
# 15  422780140      564700000                                  The Lion King
# 7   474544677      552500000            Star Wars Ep. I: The Phantom Menace
# 23  395708305      643104279                                  Jurassic Park
# 3   652198010     1018130015                                 Jurassic World
# 4   623279547      896200000                                   The Avengers
# 5   533345358      469546000                                The Dark Knight
# 11  441226247      495781885                                        Shrek 2
# 20  403706375      418000000                                     Spider-Man
# 76  285761243      190923432                                     Home Alone
# 46  330151138      349706026                                   Forrest Gump
# 14  423315812      642900000     Pirates of the Caribbean: Dead Man's Chest
# 25  380529370      555900000                                   Finding Nemo
# 27  377845905      763562762  The Lord of the Rings: The Return of the King
# 99  251188924      160160000                                         Batman
# 6   483597782      467000000                                   Finding Dory
# 28  373524485      410180516                                   Spider-Man 2
# 29  370782930      251637737                      The Passion of the Christ
# 26  380270577      468728300         Star Wars Ep. III: Revenge of the Sith
# 58  306169255      511231623                               Independence Day
# 10  448139099      636300000                          The Dark Knight Rises
# 9   459005868      945700000                        Avengers: Age of Ultron
# 38  342548984      592154195          The Lord of the Rings: The Two Towers
# ..        ...            ...                                            ...
# 62  301959197      633124489         Harry Potter and the Half-Blood Prince
# 42  336045770      827578711                                        Minions
# 44  333172112      438000000                        Guardians of the Galaxy
# 87  261441092      353285660                                The Incredibles
# 64  296623634      390934093                    The Twilight Saga: New Moon
# 45  330360194      537800000             Batman v Superman: Dawn of Justice
# 67  293004164      438538457                                             Up
# 63  300531751      405571077                     The Twilight Saga: Eclipse
# 65  295983305      664300000   Harry Potter and the Deathly Hallows: Part I
# 68  292576195      540008221                                      Inception
# 60  304360277      806166704                                        Skyfall
# 61  303003568      714000000              The Hobbit: An Unexpected Journey
# 81  277322503      188441583                                   The Hangover
# 57  308363870      392000000                                  Suicide Squad
# 69  292324737      537400000       The Twilight Saga: Breaking Dawn, Part 2
# 79  281287133      408132918       The Twilight Saga: Breaking Dawn, Part 1
# 94  256393010      329139674                                    I am Legend
# 72  291045518      376954000                                   Man of Steel
# 93  257730019      127950427                                      Star Trek
# 95  255959475       49746319                                 The Blind Side
# 77  281723902      368799525          The Hunger Games: Mockingjay - Part 2
# 82  274092705      442300000                                        Gravity
# 83  268488329      475100000                            Monsters University
# 98  251513985      291981048                                  Despicable Me
# 85  262030663      495859604                         The Amazing Spider-Man
# 97  254464305      332000000                           The Hangover Part II
# 91  258366855      702000000            The Hobbit: The Desolation of Smaug
# 90  259746958      454654931            Captain America: The Winter Soldier
# 92  257784718      199944670                                 The Lego Movie
# 96  255119788      700000000      The Hobbit: The Battle of the Five Armies
#
#      worldwide  year  adj_domestic
# 8    786598007  1977  1.906148e+09
# 89   470700000  1975  1.205553e+09
# 12   792965326  1982  1.113915e+09
# 2   2207615668  1997  9.994169e+08
# 0   2058662225  2015  9.599380e+08
# 73   534171960  1980  9.107311e+08
# 1   2783918982  2009  8.705495e+08
# 56   572705079  1983  7.623901e+08
# 15   987480140  1994  6.978105e+08
# 7   1027044677  1999  6.967526e+08
# 23  1038812584  1993  6.710783e+08
# 3   1670328025  2015  6.684049e+08
# 4   1519479547  2012  6.646387e+08
# 5   1002891358  2008  6.110760e+08
# 11   937008132  2004  5.761246e+08
# 20   821706375  2002  5.498060e+08
# 76   476684675  1990  5.453417e+08
# 46   679857164  1994  5.449237e+08
# 14  1066215812  2006  5.176305e+08
# 25   936429370  2003  5.062092e+08
# 27  1141408667  2003  5.026395e+08
# 99   411348924  1989  5.016420e+08
# 6    950597782  2016  4.920256e+08
# 28   783705001  2004  4.877241e+08
# 29   622420667  2004  4.841443e+08
# 26   848998877  2005  4.808774e+08
# 58   817400878  1996  4.799916e+08
# 10  1084439099  2012  4.778764e+08
# 9   1404705868  2015  4.704120e+08
# 38   934703179  2002  4.665160e+08
# ..         ...   ...           ...
# 62   935083686  2009  3.456513e+08
# 42  1163624481  2015  3.443964e+08
# 44   771172112  2014  3.440344e+08
# 87   614726752  2004  3.413728e+08
# 64   687557727  2009  3.395437e+08
# 45   868160194  2016  3.361175e+08
# 67   731542621  2009  3.354005e+08
# 63   706102828  2010  3.349034e+08
# 65   960283305  2010  3.298348e+08
# 68   832584416  2010  3.260380e+08
# 60  1110526981  2012  3.245568e+08
# 61  1017003568  2012  3.231101e+08
# 81   465764086  2009  3.174498e+08
# 57   700363870  2016  3.137378e+08
# 69   829724737  2012  3.117226e+08
# 79   689420051  2011  3.088385e+08
# 94   585532684  2007  3.057493e+08
# 72   667999518  2013  3.050476e+08
# 93   385680446  2009  2.950223e+08
# 95   305705794  2009  2.929956e+08
# 77   650523427  2015  2.887246e+08
# 82   716392705  2013  2.872792e+08
# 83   743588329  2013  2.814052e+08
# 98   543495033  2010  2.802795e+08
# 85   757890267  2012  2.794183e+08
# 97   586464305  2011  2.793884e+08
# 91   960366855  2013  2.707968e+08
# 90   714401889  2014  2.682154e+08
# 92   457729388  2014  2.661892e+08
# 96   955119788  2014  2.634374e+08
#
# [100 rows x 6 columns]
